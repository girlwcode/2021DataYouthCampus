# %%
#ㅋㅋㅋㅋ 이건 goorm ide로 가상환경으로 만든 파일
print("#ㅋㅋㅋㅋ 이건 goorm ide로 가상환경으로 만든 파일")
# Out:
# #ㅋㅋㅋㅋ 이건 goorm ide로 가상환경으로 만든 파일

# %% [markdown]
# # 환경 스샷
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 사용 코드
# ![image-2.png](attachment:image-2.png)
